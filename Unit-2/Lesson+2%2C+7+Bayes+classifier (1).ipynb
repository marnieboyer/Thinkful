# %% [markdown]
# ## AMAZON REVIEWS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# Grab and process the raw data.
reviews_raw = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/amazon_cells_labelled.txt", delimiter = '\t')
reviews_raw.columns = ['review', 'positive']
reviews_raw['positive'] = (reviews_raw['positive'] == 1)

# %%
reviews_raw.head()
# Out:
#                                               review positive
# 0                        Good case, Excellent value.     True
# 1                             Great for the jawbone.     True
# 2  Tied to charger for conversations lasting more...    False
# 3                                  The mic is great.     True
# 4  I have to jiggle the plug to get it to line up...    False

# %%
keywords = ['good','like','best','easy','nice','great','perfect','recommend', 'easier','love'
            ,'Beautiful',' satisfied','must have', 'happy','brilliant','well made','adorable','excellent'
           ,'priced right','quickly','comfort','sturdy','seamless','helpful','superb','tremendous','best','bargain',
            'waste','fool','do not buy','poor','disappoint',' impressed','keen','ideal','winner','favorite','no problem',
            'works well','happy','Incredible','wonderful','not good','breaks','cheap','terrible','not','better']

#pleased ~ happy

for key in keywords:
    reviews_raw[str(key)] = reviews_raw.review.str.contains(
        str(key),
        case=False
    )

target = reviews_raw['positive']

# %%
reviews_pos = reviews_raw.query('positive == True ')
reviews_neg = reviews_raw.query('positive == False ')

reviews_pos[50:100]  # Just look at positive reviews for some ideas for my keywords
reviews_neg[40:100]
# Out:
#                                                 review positive   good   like  \
# 83   This item worked great, but it broke after 6 m...    False  False  False
# 86           The construction of the headsets is poor.    False  False  False
# 89   For a product that costs as much as this one d...    False  False  False
# 92            The ear buds only play music in one ear.    False  False  False
# 93                            Dont waste your money...    False  False  False
# 95   If you plan to use this in a car forget about it.    False  False  False
# 96           I found this product to be waaay too big.    False  False  False
# 98             I'm very disappointed with my decision.    False  False  False
# 100  Buyer Beware, you could flush money right down...    False  False  False
# 103  I received my supposedly new motorola 375 and ...    False  False  False
# 105  That's a huge design flaw (unless I'm not usin...    False  False  False
# 107  The camera, although rated at an impressive 1....    False  False  False
# 108  I purcashed this for the car charger and it do...    False  False  False
# 115  i got this phone around the end of may and i'm...    False  False  False
# 120                Could not get strong enough signal.    False  False  False
# 122                                       Bad Quality.    False  False  False
# 125                Basically the service was very bad.    False  False  False
# 126  it did not work in my cell phone plug i am ver...    False  False  False
# 128            The BT headset was such a disapoinment.    False  False  False
# 133                       Buyer--Be Very Careful!!!!!.    False  False  False
# 134  The majority of the Logitech earbud headsets f...    False  False  False
# 137  In my house I was getting dropped coverage ups...    False  False  False
# 139                                      What a waste.    False  False  False
# 140  During several different 2 minute calls, I exp...    False  False  False
# 141                    I was not happy with this item.    False  False  False
# 142                                 very disappointed.    False  False  False
# 143  The phone takes FOREVER to charge like 2 to 5 ...    False  False   True
# 145                              What a waste of time!    False  False  False
# 146                   Its reception is very very poor.    False  False  False
# 147  Items stated as included from the description ...    False  False  False
# 148  After 3 months, screen just went black all of ...    False  False  False
# 149                             I Was Hoping for More.    False  False  False
# 150                  Audio Quality is poor, very poor.    False  False  False
# 153  I've bought $5 wired headphones that sound bet...    False  False  False
# 159  All I can do is whine on the Internet, so here...    False  False   True
# 161  This is essentially a communications tool that...    False  False  False
# 163  I still maintain that monkeys shouldn't make h...    False  False  False
# 165  Doesn't work at all.. I bougth it for my L7c a...    False  False  False
# 167                                 doesn't last long.    False  False  False
# 168  One thing I hate is the mode set button at the...    False  False  False
# 170                    Thank you for wasting my money.    False  False  False
# 171         How can that be?The audio quality is poor.    False  False  False
# 176  I put the latest OS on it (v1.15g), and it now...    False  False   True
# 177  It only recognizes the Phone as its storage de...    False  False  False
# 178  If you like a loud buzzing to override all you...    False  False   True
# 179                            Don't buy this product.    False  False  False
# 180  I've had this bluetoooth headset for some time...    False  False  False
# 182  I have this phone and it is a thorn in my side...    False  False  False
# 183  I recently had problems where I could not stay...    False  False  False
# 185                                      Design Flaw?.    False  False  False
# 187                                 Waste of 13 bucks.    False  False  False
# 188  But when I check voice mail at night, the keyp...    False  False  False
# 189               The replacement died in a few weeks.    False  False  False
# 192  I have had problems wit hit dropping signal an...    False  False  False
# 193                                     Not impressed.    False  False  False
# 196                                        Bad Choice.    False  False  False
# 197                     The pleather case doesn't fit.    False  False  False
# 198                        useless phone, simply deaf.    False  False  False
# 201  It makes very strange ticking noises before it...    False  False  False
# 203                    Battery lasts only a few hours.    False  False  False
#
#       best   easy   nice  great perfect recommend  ...   no problem  \
# 83   False  False  False   True   False     False  ...        False
# 86   False  False  False  False   False     False  ...        False
# 89   False  False  False   True   False     False  ...        False
# 92   False  False  False  False   False     False  ...        False
# 93   False  False  False  False   False     False  ...        False
# 95   False  False  False  False   False     False  ...        False
# 96   False  False  False  False   False     False  ...        False
# 98   False  False  False  False   False     False  ...        False
# 100  False  False  False  False   False     False  ...        False
# 103  False  False  False  False   False     False  ...        False
# 105  False  False  False  False   False     False  ...        False
# 107  False  False  False  False   False     False  ...        False
# 108  False  False  False  False   False     False  ...        False
# 115  False  False  False  False   False     False  ...        False
# 120  False  False  False  False   False     False  ...        False
# 122  False  False  False  False   False     False  ...        False
# 125  False  False  False  False   False     False  ...        False
# 126  False  False  False  False   False     False  ...        False
# 128  False  False  False  False   False     False  ...        False
# 133  False  False  False  False   False     False  ...        False
# 134  False  False  False  False   False     False  ...        False
# 137  False  False  False  False   False     False  ...        False
# 139  False  False  False  False   False     False  ...        False
# 140  False  False  False  False   False     False  ...        False
# 141  False  False  False  False   False     False  ...        False
# 142  False  False  False  False   False     False  ...        False
# 143  False  False  False  False   False     False  ...        False
# 145  False  False  False  False   False     False  ...        False
# 146  False  False  False  False   False     False  ...        False
# 147  False  False  False  False   False     False  ...        False
# 148  False  False  False  False   False     False  ...        False
# 149  False  False  False  False   False     False  ...        False
# 150  False  False  False  False   False     False  ...        False
# 153  False  False  False  False   False     False  ...        False
# 159  False  False  False  False   False     False  ...        False
# 161  False  False  False  False   False     False  ...        False
# 163  False  False  False  False   False     False  ...        False
# 165  False  False  False  False   False     False  ...        False
# 167  False  False  False  False   False     False  ...        False
# 168  False  False  False  False   False     False  ...        False
# 170  False  False  False  False   False     False  ...        False
# 171  False  False  False  False   False     False  ...        False
# 176  False  False  False  False   False     False  ...        False
# 177  False  False  False  False   False     False  ...        False
# 178  False  False  False  False   False     False  ...        False
# 179  False  False  False  False   False     False  ...        False
# 180  False  False  False  False   False     False  ...        False
# 182  False  False  False  False   False     False  ...        False
# 183  False  False  False  False   False     False  ...        False
# 185  False  False  False  False   False     False  ...        False
# 187  False  False  False  False   False     False  ...        False
# 188  False  False  False  False   False     False  ...        False
# 189  False  False  False  False   False     False  ...        False
# 192  False  False  False  False   False     False  ...        False
# 193  False  False  False  False   False     False  ...        False
# 196  False  False  False  False   False     False  ...        False
# 197  False  False  False  False   False     False  ...        False
# 198  False  False  False  False   False     False  ...        False
# 201  False  False  False  False   False     False  ...        False
# 203  False  False  False  False   False     False  ...        False
#
#     works well Incredible wonderful not good breaks  cheap terrible    not  \
# 83       False      False     False    False  False  False    False  False
# 86       False      False     False    False  False  False    False  False
# 89       False      False     False    False  False  False    False  False
# 92       False      False     False    False  False  False    False  False
# 93       False      False     False    False  False  False    False  False
# 95       False      False     False    False  False  False    False  False
# 96       False      False     False    False  False  False    False  False
# 98       False      False     False    False  False  False    False  False
# 100      False      False     False    False  False  False    False  False
# 103      False      False     False    False  False  False    False   True
# 105      False      False     False    False  False  False    False   True
# 107      False      False     False    False  False  False    False  False
# 108      False      False     False    False  False  False    False   True
# 115      False      False     False    False  False  False    False  False
# 120      False      False     False    False  False  False    False   True
# 122      False      False     False    False  False  False    False  False
# 125      False      False     False    False  False  False    False  False
# 126      False      False     False    False  False  False    False   True
# 128      False      False     False    False  False  False    False  False
# 133      False      False     False    False  False  False    False  False
# 134      False      False     False    False  False  False    False  False
# 137      False      False     False    False  False  False    False  False
# 139      False      False     False    False  False  False    False  False
# 140      False      False     False    False  False  False    False  False
# 141      False      False     False    False  False  False    False   True
# 142      False      False     False    False  False  False    False  False
# 143      False      False     False    False  False  False    False  False
# 145      False      False     False    False  False  False    False  False
# 146      False      False     False    False  False  False    False  False
# 147      False      False     False    False  False  False    False   True
# 148      False      False     False    False  False  False    False  False
# 149      False      False     False    False  False  False    False  False
# 150      False      False     False    False  False  False    False  False
# 153      False      False     False    False  False  False    False  False
# 159      False      False     False    False  False  False    False  False
# 161      False      False     False    False  False  False    False   True
# 163      False      False     False    False  False  False    False  False
# 165      False      False     False    False  False  False    False   True
# 167      False      False     False    False  False  False    False  False
# 168      False      False     False    False  False  False    False  False
# 170      False      False     False    False  False  False    False  False
# 171      False      False     False    False  False  False    False  False
# 176      False      False     False    False  False  False    False  False
# 177      False      False     False    False  False  False    False  False
# 178      False      False     False    False  False  False    False  False
# 179      False      False     False    False  False  False    False  False
# 180      False      False     False    False  False  False    False   True
# 182      False      False     False    False  False  False    False  False
# 183      False      False     False    False  False  False    False   True
# 185      False      False     False    False  False  False    False  False
# 187      False      False     False    False  False  False    False  False
# 188      False      False     False    False  False  False    False  False
# 189      False      False     False    False  False  False    False  False
# 192      False      False     False    False  False  False    False  False
# 193      False      False     False    False  False  False    False   True
# 196      False      False     False    False  False  False    False  False
# 197      False      False     False    False  False  False    False  False
# 198      False      False     False    False  False  False    False  False
# 201      False      False     False    False  False  False    False  False
# 203      False      False     False    False  False  False    False  False
#
#     better
# 83   False
# 86   False
# 89    True
# 92   False
# 93   False
# 95   False
# 96   False
# 98   False
# 100  False
# 103  False
# 105  False
# 107  False
# 108  False
# 115  False
# 120  False
# 122  False
# 125  False
# 126  False
# 128  False
# 133  False
# 134  False
# 137  False
# 139  False
# 140  False
# 141  False
# 142  False
# 143  False
# 145  False
# 146  False
# 147  False
# 148  False
# 149  False
# 150  False
# 153   True
# 159  False
# 161  False
# 163  False
# 165  False
# 167  False
# 168  False
# 170  False
# 171  False
# 176  False
# 177  False
# 178  False
# 179  False
# 180  False
# 182  False
# 183  False
# 185  False
# 187  False
# 188  False
# 189  False
# 192  False
# 193  False
# 196  False
# 197  False
# 198  False
# 201  False
# 203  False
#
# [60 rows x 49 columns]

# %%
sns.heatmap(reviews_raw.corr())
plt.show()

# %% [markdown]
# Looks like none of my words are strongly correlated with another. With independent variables, I know the Bernoulli classifier should work well.

# %%
# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()
# Fit our model to the data.
data = reviews_raw[keywords]
bnb.fit(data, target)
# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 999 points : 195

# %% [markdown]
# The accuracy of my model is = 1 - 195/999 = 80.5%

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(target, y_pred)
# NOTE - this is where I fixed my labels for the confusion matrix :)

                # Predicted
#Actual        False         True
#False      True Neg        False Pos
#True         False Neg      True Pos
# Out:
# array([[466,  33],
#        [162, 338]])

# %%
df = reviews_raw.query('positive == False') 
df.shape[0]
# Out:
# 499

# %%
print('False Positive')   # I predict it positive but it's not
print(33/(499))
# this is when they use a "this is NOT good" type of sentiment
# Out:
# False Positive
# 0.06613226452905811

# %%
print('False nEGATIVE')   # It's positive but I didn't predict that
print(162/(500))
# Out:
# False nEGATIVE
# 0.324

# %% [markdown]
# It's just like me to look for the two ways I have FAILED, so I will provide here the SENSITIVITY & SPECIFITY of my awesome model.

# %%
#Sensitivity - True Positive Rate - to rule a condition OUT
print("Sensitivity:")
print(338/500)

#Specificity - True Negatives Rate - to rule a condition IN
print("Specifity:")
print(466/499)
# Out:
# Sensitivity:
# 0.676
# Specifity:
# 0.9338677354709419

# %%
reviews_raw['y_pred'] = y_pred

# %%
validate = reviews_raw[['review','positive','y_pred']]
validate_bad = validate.query('positive == True & y_pred == False')
validate_bad.head(270)
# Out:
#                                                 review positive y_pred
# 10   He was very impressed when going from the orig...     True  False
# 22   I have yet to run this new battery below two b...     True  False
# 35                           It has kept up very well.     True  False
# 44                      It has all the features I want     True  False
# 50   good protection and does not make phone too bu...     True  False
# 51   A usable keyboard actually turns a PDA into a ...     True  False
# 54   Everything about it is fine and reasonable for...     True  False
# 79       I wear it everyday and it holds up very well.     True  False
# 81   Well packaged, arrived on time, and works as i...     True  False
# 88                              The phone loads super!     True  False
# 94                         Will order from them again!     True  False
# 111  its a little geeky but i think thats its sex o...     True  False
# 118                 )Setup couldn't have been simpler.     True  False
# 121                 Iam very pleased with my purchase.     True  False
# 123                                 Gets the job done.     True  False
# 129  It is so small and you don't even realize that...     True  False
# 144  I got this phone on reccomendation from a rela...     True  False
# 154  This phone is very fast with sending any kind ...     True  False
# 194         Light weight, I hardly notice it is there.     True  False
# 199  The color is even prettier than I thought it w...     True  False
# 212  The range is very decent, I've been able to ro...     True  False
# 213                                      fast service.     True  False
# 218              I'm still infatuated with this phone.     True  False
# 233           Really pleased with this product so far.     True  False
# 237  I was very excited to get this headset because...     True  False
# 244                                 Worth every penny.     True  False
# 260  Only had this a month but it's worked flawless...     True  False
# 272    I gave it 5 stars because of the sound quality.     True  False
# 282  I am very impressed with this headset from Pla...     True  False
# 300            Now I know that I made a wise decision.     True  False
# ..                                                 ...      ...    ...
# 816     Gets a signal when other Verizon phones won't.     True  False
# 819        Plan on ordering from them again and again.     True  False
# 822  They keep getting better and better (this is m...     True  False
# 824             The shipping time was also very quick!     True  False
# 851  I have read other's reviews here but I haven't...     True  False
# 856                                        (It works!)     True  False
# 869                                        Works fine.     True  False
# 871  I was very pleased to see that I could replace...     True  False
# 878  It seems completely secure, both holding on to...     True  False
# 883  I am pairing this with my iphone, and I could ...     True  False
# 888  It was that loud.Glad to say that the Plantron...     True  False
# 905  But despite these few flaws, this case is of e...     True  False
# 907  I can hear while I'm driving in the car, and u...     True  False
# 910  So I bought about 10 of these and saved alot o...     True  False
# 917                                      Works for me.     True  False
# 919           much better than the hard plastic cases.     True  False
# 922                                        cool phone.     True  False
# 924  Motorola finally got the voice quality of a bl...     True  False
# 933  You get extra minutes so that you can carry ou...     True  False
# 937               Logitech Bluetooth Headset is a 10!.     True  False
# 940  I have tried these cables with my computer and...     True  False
# 945  I have had mine for about a year and this Chri...     True  False
# 949                                It is a joy to use.     True  False
# 951                          Very satisifed with that.     True  False
# 953  This is the phone to get for 2005.... I just b...     True  False
# 955  Just reading on the specs alone makes you say ...     True  False
# 960  I was very impressed with the price of the cases.     True  False
# 975                                  SWEETEST PHONE!!!     True  False
# 976             :-)Oh, the charger seems to work fine.     True  False
# 977  It fits so securely that the ear hook does not...     True  False
#
# [162 rows x 3 columns]

# %%
validate_bad2 = validate.query('positive == False & y_pred == True')
print(validate_bad2)
# Out:
#                                                 review positive y_pred
# 82                      The battery runs down quickly.    False   True
# 83   This item worked great, but it broke after 6 m...    False   True
# 89   For a product that costs as much as this one d...    False   True
# 115  i got this phone around the end of may and i'm...    False   True
# 143  The phone takes FOREVER to charge like 2 to 5 ...    False   True
# 159  All I can do is whine on the Internet, so here...    False   True
# 176  I put the latest OS on it (v1.15g), and it now...    False   True
# 178  If you like a loud buzzing to override all you...    False   True
# 216  I also didn't like the "on" button, it felt li...    False   True
# 220  It's kind of embarrassing to use because of ho...    False   True
# 227  I have had this phone for over a year now, and...    False   True
# 285          I wouldn't recommend buying this product.    False   True
# 320  I ordered this product first and was unhappy w...    False   True
# 325  However-the riingtones are not the best, and n...    False   True
# 353                Excellent starter wireless headset.    False   True
# 354  The loudspeaker option is great, the bumpers w...    False   True
# 408  I came over from Verizon because cingulair has...    False   True
# 475  Uncomfortable In the Ear, Don't use with LG VX...    False   True
# 478                             I'd like to return it.    False   True
# 531  Unfortunately it's easy to accidentally activa...    False   True
# 562  If you are looking for a good quality Motorola...    False   True
# 586  Also difficult to put on.I'd recommend avoidin...    False   True
# 587  I only used it two days, and it wasn't always ...    False   True
# 743  If you like a loud buzzing to override all you...    False   True
# 766  I really wanted the Plantronics 510 to be the ...    False   True
# 770  VERY cheap plastic, creaks like an old wooden ...    False   True
# 798  I tried talking real loud but shouting on the ...    False   True
# 805  At first I thought I was grtting a good deal a...    False   True
# 836                    I don't like this Nokia either.    False   True
# 885  I didn't want the clip going over the top of m...    False   True
# 913  My phone sounded OK ( not great - OK), but my ...    False   True
# 965  however, my girl was complain that some time t...    False   True
# 984  There was so much hype over this phone that I ...    False   True

# %% [markdown]
# # Cross-Validation

# %%
#Make 5 folds
val1, val2, val3, val4, val5 = np.split(reviews_raw.sample(frac=1), [int(.2*len(reviews_raw)), int(.4*len(reviews_raw)),int(.6*len(reviews_raw)),int(.8*len(reviews_raw))])

# %%
test = val1
rest = [val2,val3,val4,val5]
train = pd.concat(rest)

# %%
data = train[keywords]
data2 = test[keywords]
target = train['positive']
# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data2)

# Display our results.
print("Number of mislabeled points out of a total {} test points in {} : {}".format(
    data2.shape[0],'val1',
    (test['positive'] != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 199 test points in val1 : 39

# %%
test = val2
rest = [val1,val3,val4,val5]
train = pd.concat(rest)

data = train[keywords]
data2 = test[keywords]
target = train['positive']
# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data2)

# Display our results.
print("Number of mislabeled points out of a total {} test points in {} : {}".format(
    data2.shape[0],'val2',
    (test['positive'] != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 200 test points in val2 : 39

# %%
test = val3
rest = [val1,val2,val4,val5]
train = pd.concat(rest)

data = train[keywords]
data2 = test[keywords]
target = train['positive']
# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data2)

# Display our results.
print("Number of mislabeled points out of a total {} test points in {} : {}".format(
    data2.shape[0],'val3',
    (test['positive'] != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 200 test points in val3 : 51

# %%
test = val4
rest = [val1,val2,val3,val5]
train = pd.concat(rest)

data = train[keywords]
data2 = test[keywords]
target = train['positive']
# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data2)

# Display our results.
print("Number of mislabeled points out of a total {} test points in {} : {}".format(
    data2.shape[0],'val4',
    (test['positive'] != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 200 test points in val4 : 45

# %%
test = val5
rest = [val1,val2,val3,val4]
train = pd.concat(rest)

data = train[keywords]
data2 = test[keywords]
target = train['positive']
# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data2)

# Display our results.
print("Number of mislabeled points out of a total {} test points in {} : {}".format(
    data2.shape[0],'val5',
    (test['positive'] != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 200 test points in val5 : 41

# %%
#So my results for my 5 folds were: 39, 39, 51,  45,  41
err = [39, 39, 51,  45,  41]
avg_error = np.mean(err)
print(avg_error)
sd_error = np.std(err)
print(sd_error)
# Out:
# 43.0
# 4.5607017004

# %% [markdown]
# # Try another distribution _ Gaussian

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
# Fit our model to the data.
data = reviews_raw[keywords]
gnb.fit(data, target)
# Classify, storing the result in a new variable.
y_pred = gnb.predict(data)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 999 points : 356

# %%
# Bernoulli was better

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()

# %%
# Fit our model to the data.
data = reviews_raw[keywords]
mnb.fit(data, target)
# Classify, storing the result in a new variable.
y_pred = mnb.predict(data)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 999 points : 347

# %%
# Bernoulli was better than Multinomial, but similar to Gaussian

# %%
# Try this model on another dataset: yelp

# %% [markdown]
# ## Yelp dataset

# %%
# Grab and process the raw data.
yelp_reviews_raw = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/yelp_labelled.txt", delimiter = '\t')
yelp_reviews_raw.columns = ['review', 'positive']
yelp_reviews_raw['positive'] = (yelp_reviews_raw['positive'] == 1)

# %%
for key in keywords:#Using keywords from above
    yelp_reviews_raw[str(key)] = yelp_reviews_raw.review.str.contains(
        str(key),
        case=False
    )

target = yelp_reviews_raw['positive']

# %%
sns.heatmap(yelp_reviews_raw.corr())
plt.show()

# %% [markdown]
# You can see that some of my words aren't in the dataset. A few more of these are correlated, such as "beautiful" & "excellent". This may impact the model but will leave for now.

# %%
# Fit our model to the data.
data_yelp = yelp_reviews_raw[keywords]
bnb.fit(data_yelp, target)
# Classify, storing the result in a new variable.
y_pred = bnb.predict(data_yelp)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data_yelp.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 999 points : 282

# %% [markdown]
# This is almost double the error compared to the Amazon dataset, some of the features are not relevant

# %% [markdown]
# ## IMBD database

# %%
# try on the IMBD database
# Grab and process the raw data.
i_reviews_raw = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/imdb_labelled.txt", delimiter = '\t')
i_reviews_raw.columns = ['review', 'positive']
i_reviews_raw['positive'] = (i_reviews_raw['positive'] == 1)

# %%
for key in keywords:#Using keywords from above
    i_reviews_raw[str(key)] = i_reviews_raw.review.str.contains(
        str(key),
        case=False
    )

target = i_reviews_raw['positive']

# %%
sns.heatmap(i_reviews_raw.corr())
plt.show()

# %%
# Fit our model to the data.
data_i = i_reviews_raw[keywords]
bnb.fit(data_i, target)
# Classify, storing the result in a new variable.
y_pred = bnb.predict(data_i)
# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data_i.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 747 points : 251

# %% [markdown]
# This model didn't work that well - more errors with fewer data points

# %% [markdown]
# Include your model and a brief writeup of your feature engineering and selection process to submit and review with your mentor.

# %% [raw]
# For this model, I used the Bernoulli classifier model because 1) I wanted to classify the reviews as either Positive or not Positive. And 2) My predictor variables (keywords) were boolean (True/False). My feature selection was based on reviewing the positive reviews (based on known information) and then trying to determine words or phrases that appear in reviews that correlate with reviews that are considered positive.  In addition, I made sure my keywords were independent of one another which is expected with a Naive Bayes classifier.
#
# As I said on the meeting, I did a lot of work and made some decisions without documenting them (I know, bad!). For example, I found situations where adding a variable actually hurt the accuracy of my model. I would add a few more True Positives but also more False Positives, so I threw out some features as a result. There were words that would be used for positive and non-positive reviews which would cause problems. I also removed any features (words) that were correlated with each other because the model assumes they are all independent.
