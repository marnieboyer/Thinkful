# %% [markdown]
# # Hello - this is my very FIRST Python project. Ever. So - first, please forgive me if I use very complex syntax for something that can be done easily in one line :) But, second, I am very proud of my first project and hope you enjoy it too!
#
# ## My project utilizes data from Kaggle for the Boston Marathon runner times from 2015 through 2017. The data set includes demographics (runner names, age, gender city, state, country) as well as their split and finish times between the first 5K and the final official time.  Since this is my first project, I will play around with some simple data to start and continue to enhance my project as I learn.

# %% [markdown]
# ### Import my data sets - first I downloaded from Kaggle, saved on my PC and them imported below

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
df15  = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/marathon_results_2015.csv")
df16  = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/marathon_results_2016.csv")
df17 = pd.read_csv("C:/Users/boyerm/Documents/Thinkful/marathon_results_2017.csv")

# %% [markdown]
# ### Giving my dataframes column names; note that 2016 did not have an index.

# %%
df15.columns = ['index','bib', 'name', 'age', 'gender','city','state','country','citizen','blank','5k','10k','15k','20k','half','25k',
               '30k','35k','40k','pace','proj_time','official_time','overall','gender_place','division']
df16.columns = ['bib', 'name', 'age', 'gender','city','state','country','citizen','blank','5k','10k','15k','20k','half','25k',
               '30k','35k','40k','pace','proj_time','official_time','overall','gender_place','division']
df17.columns = ['index','bib', 'name', 'age', 'gender','city','state','country','citizen','blank','5k','10k','15k','20k','half','25k',
               '30k','35k','40k','pace','proj_time','official_time','overall','gender_place','division']

# %%
print(df16.columns)
#just checking
# Out:
# Index(['bib', 'name', 'age', 'gender', 'city', 'state', 'country', 'citizen',
#        'blank', '5k', '10k', '15k', '20k', 'half', '25k', '30k', '35k', '40k',
#        'pace', 'proj_time', 'official_time', 'overall', 'gender_place',
#        'division'],
#       dtype='object')

# %%
print(df16.sample(10))
#just checking
# Out:
#          bib                   name  age gender             city state  \
# 21197  19854        Cash, Michael S   57      M           Durham    NC
# 15189  27368      Andretta, Antonio   44      M            Miami    FL
# 14853  11323         O'Brien, Peggy   57      F        Ferryland    NL
# 7272    1940      Viavattine, Joe R   21      M  Vadnais Heights    MN
# 24941  27232    Cargill, Stephen W.   26      M           Boston    MA
# 17605  16817         Bade, Sharon M   53      F      Frankenmuth    MI
# 9144    8906  Benjamin, Christopher   40      M    Harrisonville    MO
# 21184  14795          Kim, Hwan Sik   58      M            Seoul   NaN
# 5508    9493       Fischer, Paul E.   55      M       Swarthmore    PA
# 16062  22064     Barrett, Joanne M.   45      F        Lehighton    PA
#
#       country citizen blank       5k   ...         25k      30k      35k  \
# 21197     USA     NaN   NaN  0:27:44   ...     2:25:46  2:57:48  3:32:42
# 15189     USA     ECU   NaN  0:26:25   ...     2:13:36  2:42:25  3:12:42
# 14853     CAN     NaN   NaN  0:22:51   ...     2:07:16  2:38:04  3:09:20
# 7272      USA     NaN   NaN  0:19:59   ...     1:43:08  2:06:43  2:36:25
# 24941     USA     NaN   NaN  0:29:38   ...     2:41:18  3:25:48  4:06:43
# 17605     USA     NaN   NaN  0:23:58   ...     2:15:37  2:47:13  3:19:35
# 9144      USA     NaN   NaN  0:23:52   ...     2:04:13  2:31:16  2:58:11
# 21184     KOR     NaN   NaN  0:25:13   ...     2:15:14  2:51:28  3:30:45
# 5508      USA     NaN   NaN  0:20:16   ...     1:50:04  2:15:30  2:42:45
# 16062     USA     NaN   NaN  0:26:55   ...     2:17:06  2:46:34  3:16:33
#
#            40k     pace proj_time official_time overall gender_place division
# 21197  4:08:06  0:10:07   4:24:56       4:24:56   21197        12048     1272
# 15189  3:42:45  0:08:57   3:54:16       3:54:16   15189         9554     1542
# 14853  3:39:36  0:08:54   3:53:08       3:53:08   14853         5429       68
# 7272   3:14:36  0:07:58   3:28:33       3:28:33    7272         5772     2909
# 24941  4:50:22  0:11:47   5:08:52       5:08:52   24941        13771     4566
# 17605  3:49:40  0:09:19   4:03:55       4:03:55   17605         7041      569
# 9144   3:23:51  0:08:12   3:34:44       3:34:44    9144         6821     1234
# 21184  4:07:42  0:10:06   4:24:48       4:24:48   21184        12041     1270
# 5508   3:09:54  0:07:43   3:22:19       3:22:19    5509         4627       89
# 16062  3:44:58  0:09:03   3:57:15       3:57:15   16062         6160      828
#
# [10 rows x 24 columns]

# %%
df16[df16['5k'] =='25k']
# Out:
# Empty DataFrame
# Columns: [bib, name, age, gender, city, state, country, citizen, blank, 5k, 10k, 15k, 20k, half, 25k, 30k, 35k, 40k, pace, proj_time, official_time, overall, gender_place, division]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### Note that some of the columns had missing data, for example, there were records with no 25K time

# %%
df17[df17['25k'].str.contains("-")]
# Out:
#        index    bib                     name  age gender             city  \
# 366      366   1132        Doucet, Shelley A   33      F       Quispamsis
# 1574    1574   5069          Schaar, Matthew   36      M    San Francisco
# 2131    2131   6521           Cadena, Daniel   40      M           Bogota
# 4198    4198   5576            Cassidy, Glyn   37      M          Killara
# 5426    5426  21812          Reilly, Karen M   54      F        San Diego
# 6047    6047   9295        Massefski, Walter   56      M           Sharon
# 8650    8650  13878    Hildebrandt, Nicole T   35      F         New York
# 8990    8990  11532       Humber, Richard S.   52      M        Brantford
# 10193  10193  10860        Cimadoro, Richard   49      M    Thousand Oaks
# 10633  10633  13715          Wilson, Annette   35      F        Millville
# 11300  11300   3619               Chan, Eric   40      M       North York
# 11989  11989  27013         Kennedy, Kate J.   35      F           Woburn
# 12624  12624  19336         Arnold, Abrea D.   37      F          Garland
# 12964  12964  12299             Stoner, Lily   31      F         New York
# 13097  13097  20378            Gonder, Renee   48      F    Mechanicsburg
# 13591  13591  19169        Stoller, Angie D.   44      F          Phoenix
# 13903  13903   9760       Hauptman, Roger M.   52      M           Upland
# 14411  14411  27448       Pitman, William F.   28      M           Boston
# 15304  15304    424      Mackinnon, Grant E.   21      M            Salem
# 15534  15534  30569           Helm, Kevin F.   26      M      Charlestown
# 15659  15659  22945        Castle, Daniel D.   42      M      Black River
# 15888  15888  22590      Duchossois, Frank L   60      M            Solon
# 16367  16367  24563           Salazar, Tania   61      F           México
# 16658  16658  13958            Hartlage, Tim   55      M     West Chester
# 22341  0:10:45         -       4:41:42   22343        12626     4267
# 22634  0:10:52         -       4:44:48   22636         9880     1600
# 22691  0:10:54         -       4:45:23   22693         9907     1604
# 23011  0:11:01         -       4:48:45   23013        12921     1751
# 23136  0:11:04         -       4:50:01   23138        12978     1755
# 23809  0:11:23         -       4:58:18   23811        10527     1087
# 24145  0:11:34         -       5:03:08   24147        10705     5235
# 26121  0:13:28         -       5:52:47   26123        11809     1207
# 26132  0:13:29         -       5:53:06   26134        11812     5781
#
# [40 rows x 25 columns]

# %% [markdown]
# ### Just wondering how long my dataset is:

# %%
len(df15.index)
# Out:
# 26598

# %% [markdown]
# ### My first visualizations!  I wanted to know what the age distribution of the runners were each year. I also decided that I will color code the years and keep that consistent throughout my project

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.hist(df15['age'], color='green', bins = np.arange(15,80))
plt.title('2015 participants') 
plt.xlabel('Age groups')
plt.ylabel('Number of Runners')

plt.subplot(1,3,2)
plt.hist(df16['age'], color='purple', bins = np.arange(15,80))
plt.title('2016 participants') 
plt.xlabel('Age groups')
plt.ylabel('Number of Runners')

plt.subplot(1,3,3)
plt.hist(df17['age'], color='red', bins = np.arange(15,80))
plt.title('2017 participants') 
plt.xlabel('Age groups')
plt.ylabel('Number of Runners')

# %%
plt.boxplot(df17['age'])
# just playing around, not that interesting though
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xc416cf8>],
#  'caps': [<matplotlib.lines.Line2D at 0xc426ba8>,
#   <matplotlib.lines.Line2D at 0xc42c7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc2f2860>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xc42c9b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xc416eb8>,
#   <matplotlib.lines.Line2D at 0xc426a90>]}

# %%
np.mean(df15['age'])
# Out:
# 42.14482291901647

# %%
np.mean(df16['age'])
# Out:
# 42.514044310927524

# %%
np.mean(df17['age'])
# Out:
# 42.587731919727375

# %% [markdown]
# ### Now, I want to look at average performance at the marathon by age group. This is when I realized that my times were not being treated as times and I had to figure out how to make the times I received in Kaggle into times I could use with computations.

# %%
df15.groupby('age').mean()
# Out:
#             index       overall  gender_place     division
# age
# 18   15787.650000  15788.650000   7699.500000  3663.200000
# 19   12145.490566  12146.490566   5833.735849  2910.018868
# 20   13056.927835  13057.927835   5955.020619  3138.453608
# 21   14054.615385  14055.615385   6627.318681  3321.483516
# 22   13634.701887  13635.701887   6147.939623  3136.267925
# 23   11531.831169  11532.831169   4882.785714  2672.902597
# 24   11978.035461  11979.035461   5078.926714  2740.692671
# 25   11391.676190  11392.676190   4816.647619  2587.777143
# 26   11690.836237  11691.836237   5219.513937  2737.327526
# 27   10977.592471  10978.592471   4702.513912  2550.111293
# 28   10855.366387  10856.366387   4723.225210  2583.917647
# 29   11131.967492  11132.967492   5052.969040  2700.201238
# 30   11428.500000  11429.500000   5091.189369  2671.882060
        time = hours*60 + mins + np.true_divide(sec,60)
        return time
    else:
        return -1

# %%
time_to_min('1:55:44')
# Out:
# 115.73333333333333

# %%
# This was from the same person - I used his "apply" function and "lambda" but pretty sure 
##I could not have figured this out myself. I got close but couldn't quite deal with all of the issues.

df15['5K_mins'] = df15['5k'].apply(lambda x: time_to_min(x))
df15['10K_mins'] = df15['10k'].apply(lambda x: time_to_min(x))
df15['15K_mins'] = df15['15k'].apply(lambda x: time_to_min(x))
df15['20K_mins'] = df15['20k'].apply(lambda x: time_to_min(x))
df15['half_mins'] = df15['half'].apply(lambda x: time_to_min(x))
df15['25K_mins'] = df15['25k'].apply(lambda x: time_to_min(x))
df15['30k_mins'] = df15['30k'].apply(lambda x: time_to_min(x))
df15['35k_mins'] = df15['35k'].apply(lambda x: time_to_min(x))
df15['40k_mins'] = df15['40k'].apply(lambda x: time_to_min(x))
df15['total_mins'] = df15['official_time'].apply(lambda x: time_to_min(x))

# %%
df16['5K_mins'] = df16['5k'].apply(lambda x: time_to_min(x))
df16['10K_mins'] = df16['10k'].apply(lambda x: time_to_min(x))
df16['15K_mins'] = df16['15k'].apply(lambda x: time_to_min(x))
df16['20K_mins'] = df16['20k'].apply(lambda x: time_to_min(x))
df16['half_mins'] = df16['half'].apply(lambda x: time_to_min(x))
df16['25K_mins'] = df16['25k'].apply(lambda x: time_to_min(x))
df16['30k_mins'] = df16['30k'].apply(lambda x: time_to_min(x))
df16['35k_mins'] = df16['35k'].apply(lambda x: time_to_min(x))
df16['40k_mins'] = df16['40k'].apply(lambda x: time_to_min(x))
df16['total_mins'] = df16['official_time'].apply(lambda x: time_to_min(x))

# %%
df17['5K_mins'] = df17['5k'].apply(lambda x: time_to_min(x))
df17['10K_mins'] = df17['10k'].apply(lambda x: time_to_min(x))
df17['15K_mins'] = df17['15k'].apply(lambda x: time_to_min(x))
df17['20K_mins'] = df17['20k'].apply(lambda x: time_to_min(x))
df17['half_mins'] = df17['half'].apply(lambda x: time_to_min(x))
df17['25K_mins'] = df17['25k'].apply(lambda x: time_to_min(x))
df17['30k_mins'] = df17['30k'].apply(lambda x: time_to_min(x))
df17['35k_mins'] = df17['35k'].apply(lambda x: time_to_min(x))
df17['40k_mins'] = df17['40k'].apply(lambda x: time_to_min(x))
df17['total_mins'] = df17['official_time'].apply(lambda x: time_to_min(x))

# %% [markdown]
# ### OK, now if I run all of the averages, will all of my times show up? YES! Success

# %%
df17.groupby('age').mean()
# Out:
#             index       overall  gender_place     division    5K_mins  \
# age
# 18   16504.950000  16506.750000   8218.200000  3959.850000  28.779167
# 19   14942.418605  14944.209302   7373.790698  3334.162791  26.518992
# 20   12809.566265  12811.253012   6261.012048  3052.409639  25.033333
# 21   11683.319728  11684.979592   5514.632653  2743.000000  24.135034
# 22   12945.866667  12947.561905   5991.619048  2999.133333  25.512698
# 23   12247.159609  12248.807818   5539.377850  2816.091205  25.206406
# 24   12771.453333  12773.142222   5804.566667  2878.555556  25.694333
# 58   204.209420  237.111401  251.451884
# 59   207.061033  240.401878  254.800998
# 60   210.993496  245.697053  260.524356
# 61   209.050669  244.902483  259.782330
# 62   214.892312  249.125523  263.928844
# 63   215.885244  249.858811  264.586093
# 64   217.489031  252.146154  267.270655
# 65   221.476471  257.613636  273.378520
# 66   225.029440  261.371898  277.261557
# 67   221.026333  255.920333  271.221500
# 68   226.905473  263.109453  279.028358
# 69   231.137943  266.734397  282.463121
# 70   230.551923  268.554701  285.140171
# 71   239.879333  279.036667  296.263333
# 72   230.507895  268.138596  284.820175
# 73   248.471212  287.612879  304.669697
# 74   241.480392  279.235294  295.616667
# 75   253.973333  292.595556  309.211111
# 76   236.956667  277.375000  294.536667
# 77   248.836667  285.300000  300.970000
# 78   242.412500  278.912500  296.879167
# 79   231.450000  264.888889  279.572222
# 80   222.383333  258.838889  273.505556
# 81   239.583333  283.083333  304.000000
# 83   229.083333  267.550000  284.650000
# 84   298.000000  343.733333  364.116667
#
# [66 rows x 14 columns]

# %% [markdown]
# ## Ok, I found another issue...this scatter plot is a mess! I need to find a way to graph averages over age, not individuals.

# %%
plt.scatter(x = df16['age'], y = df16['total_mins'])
plt.show()

# %% [markdown]
# ## So, I will make a df of the averages, grouping by age (for each year). Note, the index = false will be important for graphing.

# %%
df15avg = df15.groupby(['age'], as_index=False).mean()

# %%
df16avg = df16.groupby(['age'], as_index=False).mean()

# %%
df17avg = df17.groupby(['age'], as_index=False).mean()

# %% [markdown]
# ## Print the new average dataframe

# %%
print(df15avg.sample(10))
# Out:
#     age         index       overall  gender_place     division    5k_mins  \
# 24   42  12318.393902  12319.393902   6053.981707  1008.257317  25.012866
# 6    24  11978.035461  11979.035461   5078.926714  2740.692671  24.914657
# 53   71  22777.256410  22778.256410  12513.025641    56.256410  30.108120
# 9    27  10977.592471  10978.592471   4702.513912  2550.111293  24.513830
# 2    20  13056.927835  13057.927835   5955.020619  3138.453608  25.182474
# 0    18  15787.650000  15788.650000   7699.500000  3663.200000  25.455833
# 19   37  11294.335106  11295.335106   5230.864362  2825.755319  24.729388
# 31   49  14081.215805  14082.215805   7283.066869  1138.363222  25.846302
# 48   66  21235.251908  21236.251908  11632.694656   162.633588  28.834224
# 64   82  25053.250000  25054.250000  13256.250000     4.250000  33.837500
#
#      10k_mins    15k_mins    20k_mins   half_mins    25k_mins    30k_mins  \
# 24  49.827236   74.866280  100.245000  105.912561  126.280569  153.383618
# 6   49.846414   74.823877  100.333688  105.838928  126.022380  153.475217
# 53  60.649573   91.977778  124.391453  131.382051  157.614103  193.212821
# 9   48.987698   73.486607   98.274195  103.667785  123.328396  149.962657
# 2   50.761168   76.108935  103.404811  108.010653  130.294845  158.350000
# 0   53.623333   75.080833  100.841667  106.329167  135.595833  166.138333
# 19  49.101219   73.775266   98.844681  104.274978  124.426729  151.048160
# 31  51.511677   77.354939  103.827584  109.324443  130.637538  158.286120
# 48  57.751781   87.378626  118.091349  124.694402  149.513486  181.383715
# 64  68.383333  104.479167  142.379167  150.758333  180.920833  221.645833
#
#       35k_mins    40k_mins  total_mins
# 24  181.294736  208.872398  220.989085
# 6   181.074980  208.899567  221.769110
# 53  230.474786  266.935043  283.083761
# 9   176.625014  204.581942  216.933279
# 2   187.172165  215.433505  227.611856
# 0   196.279167  226.720833  239.657500
# 19  177.219260  205.260971  217.407735
# 31  187.887487  216.612589  229.239032
# 48  217.342875  251.464122  266.583461
# 64  263.508333  304.616667  322.620833

# %%
df15avg.columns = ['age','index','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %%
df16avg.columns = ['age','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %%
df17avg.columns = ['age','index','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %% [markdown]
# ## I want to see how finish time changes by age of runner

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.scatter(x = df15avg['age'], y = df15avg['total_mins'],color = 'green')
plt.title('2015 Finish Time by Age') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')

plt.subplot(1,3,2)
plt.scatter(x = df16avg['age'], y = df16avg['total_mins'],color = 'purple')
plt.title('2016 Finish Time by Age') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')

plt.subplot(1,3,3)
plt.scatter(x = df17avg['age'], y = df17avg['total_mins'],color = 'red')
plt.title('2017 Finish Time by Age') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')

# %% [markdown]
# ## As you can see, runners under the age of 30 run slower than their older (and wiser) counterparts over 30. However, as the runners continue to age, their average finish times continue to increase.

# %% [markdown]
# ## But what I know about running, there's a big difference between male and female running times, so I want to break my df into age AND gender

# %%
df15avg_gen = df15.groupby(['age','gender'], as_index = False).mean()

# %%
df16avg_gen = df16.groupby(['age','gender'], as_index = False).mean()

# %%
df17avg_gen = df17.groupby(['age','gender'], as_index = False).mean()

# %% [markdown]
# ## Hmmm, wonder if that worked? I'll print my new df to be sure

# %%
print(df16avg_gen.sample(10))
# Out:
#     age gender       overall  gender_place     division    5k_mins   10k_mins  \
# 67   51      M  12359.927438   8005.721088  1009.877551  24.365949  49.046523
# 39   37      M   8355.163934   5540.091803  2448.196721  22.907760  45.497596
# 82   59      F  20636.671233   8795.191781   360.561644  28.478767  57.936301
# 98   67      F  24053.250000  10704.000000    66.625000  31.622917  65.005208
# 70   53      F  17774.683721   7163.502326   618.786047  27.077752  54.757907
# 95   65      M  19377.328571  11310.635714   203.078571  27.669286  55.980595
# 53   44      M   9515.751295   6328.932642  1030.935233  23.485017  47.026295
# 73   54      M  13468.632588   8533.466454  1090.396166  25.122417  50.687859
# 96   66      F  22350.913043   9742.695652    51.782609  30.182609  61.592029
# 60   48      F  17095.936306   6792.550955   988.121019  26.941083  54.433015
#
#      15k_mins    20k_mins   half_mins    25k_mins    30k_mins    35k_mins  \
# 67  74.165986  100.225699  105.854649  126.968821  155.324981  185.756349
# 39  68.964645   92.640328   98.134317  117.696557  144.252186  172.312240
# 82  87.941553  119.138356  125.721918  150.931279  184.699087  219.654566
# 98  98.830208  133.673958  141.056250  169.235417  207.616667  247.177083
# 70  83.078527  112.240543  118.542403  142.112248  173.673178  206.461163
# 95  84.832857  114.625595  121.033452  145.271429  178.363333  213.547619
# 53  71.064637   95.497064  101.156865  121.219689  148.259629  177.009456
# 73  76.585144  103.484718  108.953035  131.134665  160.419063  191.675453
# 96  94.043478  127.850000  135.065217  162.411594  198.463043  234.940580
# 60  82.470329  111.375372  117.598567  140.898514  172.140658  203.903662
#
#       40k_mins  total_mins
# 67  215.879667  229.697279
# 39  199.936284  212.668907
# 82  253.700913  268.538128
# 98  285.312500  302.081250
# 70  238.607209  252.492946
# 95  248.625238  263.830000
# 53  205.319085  218.157599
# 73  223.056550  236.520394
# 96  269.848551  284.951449
# 60  236.404352  250.153238

# %%
df15avg_gen.columns = ['age','gender','index','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %%
df16avg_gen.columns = ['age','gender','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %%
df17avg_gen.columns = ['age','gender','index','overall','gender_place','division','5k_mins','10k_mins','15k_mins','20k_mins','half_mins','25k_mins','30k_mins','35k_mins','40k_mins','total_mins']

# %% [markdown]
# ## There's probably a better way to reduce this df but for now, I'm going to split the df into 2 male and female dfs

# %%
df15avg_fem = df15avg_gen[df15avg_gen['gender'] =='F']
df15avg_male = df15avg_gen[df15avg_gen['gender'] =='M']

df16avg_fem = df16avg_gen[df15avg_gen['gender'] =='F']
df16avg_male = df16avg_gen[df15avg_gen['gender'] =='M']

df17avg_fem = df17avg_gen[df15avg_gen['gender'] =='F']
df17avg_male = df17avg_gen[df15avg_gen['gender'] =='M']

# %%
print(df17avg_fem.sample(10))
# Out:
#      age gender         index       overall  gender_place     division  \
# 110   73      F  23399.333333  23401.333333  10301.333333    11.000000
# 22    29      F  13449.800000  13451.583784   4996.964865  2806.235135
# 50    43      F  15542.592486  15544.526012   5975.878613   967.667630
# 70    53      F  17533.509709  17535.490291   7044.402913   604.830097
# 12    24      F  14712.346154  14714.143357   5696.797203  3097.300699
# 46    41      F  14982.679293  14984.626263   5652.790404   916.805556
# 40    38      F  13931.519553  13933.374302   5163.340782  2946.798883
# 42    39      F  13968.266484  13970.156593   5158.145604  2962.791209
# 68    52      F  17702.951220  17704.939024   7109.646341   604.987805
# 56    46      F  16496.004854  16497.968447   6470.063107   942.762136
#
#        5k_mins   10k_mins   15k_mins    20k_mins   half_mins    25k_mins  \
# 110  30.233333  61.383333  94.011111  128.938889  136.422222  164.738889
# 49   143.869153  170.133411  196.343395  207.913520
# 43   141.955538  167.892372  194.521003  206.057367
# 51   146.051196  172.871486  200.581594  212.550217
# 109  196.584211  236.085965  256.731579  291.102632

# %% [markdown]
# ### OK, now I want to make some cool graphs - comparing females and males by year (6 total plots). Here goes.

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(hspace=.5)
yl = 180
yu = 340

plt.subplot(3,2,1)
plt.scatter(x = df15avg_male['age'], y = df15avg_male['total_mins'],color = 'green')
plt.title('2015 Finish Time by Age - Males Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
plt.ylim([yl, yu])

plt.subplot(3,2,2)
plt.scatter(x = df15avg_fem['age'], y = df15avg_fem['total_mins'],color = 'lightgreen')
plt.title('2015 Finish Time by Age - Females Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
plt.ylim([yl, yu])

plt.subplot(3,2,3)
plt.scatter(x = df16avg_male['age'], y = df16avg_male['total_mins'],color = 'purple')
plt.title('2016 Finish Time by Age - Males Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
plt.ylim([yl, yu])

plt.subplot(3,2,4)
plt.scatter(x = df16avg_fem['age'], y = df16avg_fem['total_mins'],color = 'pink')
plt.title('2016 Finish Time by Age - Females Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
plt.ylim([yl, yu])

plt.subplot(3,2,5)
plt.scatter(x = df17avg_male['age'], y = df17avg_male['total_mins'],color = 'red')
plt.title('2017 Finish Time by Age - Males Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
plt.ylim([yl, yu])

plt.subplot(3,2,6)
plt.scatter(x = df17avg_fem['age'], y = df17avg_fem['total_mins'],color = 'orange')
plt.title('2017 Finish Time by Age - Females Only') 
plt.xlabel('Age groups')
plt.ylabel('Finish Time (in minutes)')
format(np.mean(df15avg_fem['age']))
plt.ylim([yl, yu])
# Out:
# (180, 340)

# %% [markdown]
# ### Cool, those graphs look nice.  I matched up all of the axes so we can compare. Clearly, women are slower than men - age for age.
#
# ### So, now I want to find some average stats. I am sure there's a better way, but here are some stats I want to find:

# %%
fem15age = format(np.mean(df15avg_fem['age']))
fem155k = np.mean(df15avg_fem['5k_mins'])
fem15time = np.mean(df15avg_fem['total_mins'])
fem15age = fem15age[:2]
fem15time = round(fem15time,1)
fem155k = round(fem155k,1)

fem16age = format(np.mean(df16avg_fem['age']))
fem165k = np.mean(df16avg_fem['5k_mins'])
fem16time = np.mean(df16avg_fem['total_mins'])
fem16age = fem16age[:2]
fem16time = round(fem16time,1)
fem165k = round(fem165k,1)

fem17age = format(np.mean(df17avg_fem['age']))
fem175k = np.mean(df17avg_fem['5k_mins'])
fem17time = np.mean(df17avg_fem['total_mins'])
fem17age = fem17age[:2]
fem175k = round(fem175k,1)

age_trend_fem = []
age_trend_fem.append(fem15age)
age_trend_fem.append(fem16age)
age_trend_fem.append(fem17age)

_5k_trend_fem = []
_5k_trend_fem.append(fem155k)
_5k_trend_fem.append(fem165k)
_5k_trend_fem.append(fem175k)

time_trend_fem = []
time_trend_fem.append(fem15time)
time_trend_fem.append(fem16time)
time_trend_fem.append(fem17time)

# %% [markdown]
# ### So, I am going to write some sentences so I can think about the trends over the three years."

# %%
print("In 2015, the average age of a female runner in the Boston Marathon was " + fem15age + " and the average finish time for the females was " + str(fem15time) + " minutes.")
print("Also, the average 5k time for the females was " + str(fem155k)+ " minutes.")
print("In 2016, the average age of a female runner in the Boston Marathon was " + fem16age + " and the average finish time for the females was " + str(fem16time) + " minutes.")
print("Also, the average 5k time for the females was " + str(fem165k)+ " minutes.")
print("In 2017, the average age of a female runner in the Boston Marathon was " + fem17age + " and the average finish time for the females was " + str(fem17time) + " minutes.")
print("Also, the average 5k time for the females was " + str(fem175k)+ " minutes.")
# Out:
# In 2015, the average age of a female runner in the Boston Marathon was 47 and the average finish time for the females was 253.0 minutes.
# Also, the average 5k time for the females was 27.9 minutes.
# In 2016, the average age of a female runner in the Boston Marathon was 47 and the average finish time for the females was 260.7 minutes.
# Also, the average 5k time for the females was 27.8 minutes.
# In 2017, the average age of a female runner in the Boston Marathon was 47 and the average finish time for the females was 263.4410809057759 minutes.
# Also, the average 5k time for the females was 28.1 minutes.

# %%
male15age = format(np.mean(df15avg_male['age']))
male155k = np.mean(df15avg_male['5k_mins'])
male15time = np.mean(df15avg_male['total_mins'])
male15age = male15age[:2]
male15time = round(male15time,1)
male155k = round(male155k,1)

male16age = format(np.mean(df16avg_male['age']))
male165k = np.mean(df16avg_male['5k_mins'])
male16time = np.mean(df16avg_male['total_mins'])
male16age = male16age[:2]
male16time = round(male16time,1)
male165k = round(male165k,1)

male17age = format(np.mean(df17avg_male['age']))
male175k = np.mean(df17avg_male['5k_mins'])
male17time = np.mean(df17avg_male['total_mins'])
male17age = male17age[:2]
male17time = round(male17time,1)
male175k = round(male175k,1)

age_trend_male = []
age_trend_male.append(male15age)
age_trend_male.append(male16age)
age_trend_male.append(male17age)

_5k_trend_male = []
_5k_trend_male.append(male155k)
_5k_trend_male.append(male165k)
_5k_trend_male.append(male175k)

time_trend_male = []
time_trend_male.append(male15time)
time_trend_male.append(male16time)
time_trend_male.append(male17time)

# %%
print("In 2015, the average age of a male runner in the Boston Marathon was " + male15age + " and the average finish time for the males was " + str(male15time) + " minutes.")
print("Also, the average 5k time for the females was " + str(male155k)+ " minutes.")
print("In 2016, the average age of a male runner in the Boston Marathon was " + male16age + " and the average finish time for the males was " + str(male16time) + " minutes.")
print("Also, the average 5k time for the females was " + str(male165k)+ " minutes.")
print("In 2017, the average age of a male runner in the Boston Marathon was " + male17age + " and the average finish time for the males was " + str(male17time) + " minutes.")
print("Also, the average 5k time for the females was " + str(male175k)+ " minutes.")
# Out:
# In 2015, the average age of a male runner in the Boston Marathon was 50 and the average finish time for the males was 234.0 minutes.
# Also, the average 5k time for the females was 25.7 minutes.
# In 2016, the average age of a male runner in the Boston Marathon was 50 and the average finish time for the males was 242.7 minutes.
# Also, the average 5k time for the females was 25.6 minutes.
# In 2017, the average age of a male runner in the Boston Marathon was 50 and the average finish time for the males was 245.5 minutes.
# Also, the average 5k time for the females was 25.8 minutes.

# %% [markdown]
# ## So, I see that the times got slower over the years for both males and females even though the avg age of particpants did not change.  Additionally, in 2016, the 5K average time was actually a little bit faster than 2015.  This made me reflect on my experience with running and the Boston Marathon. Since the marathon is run in April, the weather for the marathon is quite variable.  Warm temps and sun is just as likely as a chilly rain.  Since the marathon is run pretty early in the morning, the weather would impact the finish times more than the earlier times (for example, the first 5K). So, I took a look at Weather Underground data and found the mean, min and max temp for the respective April Mondays on which the Boston Marathon was run in 2015, 16, and 17.

# %%
# data to plot
n_groups = 3
meantemp = [46,55,62]
maxtemp = [51,67,75]
mintemp = [41,42,49]

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.25
opacity = 0.65
 
rects1 = plt.bar(index, meantemp, bar_width,
                 alpha=opacity,
                 color='orange',
                 label='Average Temp')
 
rects2 = plt.bar(index + bar_width, maxtemp, bar_width,
                 alpha=opacity,
                 color='red',
                 label='Max Temp')

rects3 = plt.bar(index + bar_width*2, mintemp, bar_width,
                 alpha=opacity,
                 color='blue',
                 label='Min Temp')
 
plt.xlabel('Year')
plt.ylabel('Temp (F)')
plt.title('Weather Conditions by year')
plt.xticks(index + bar_width , ('2015', '2016', '2017'))
plt.legend()
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interesting, the average and max temps were definitely warmer between 2015 and 2016 and also from 2016 to 2017 which could have impacted finish times year-over-year.  Min temps were all about the same, which may contribute to the closer 5K times.

# %% [markdown]
# ### Some more graphs of the trends over time for males/females for 5K and finish times. I compared this as a time series vs. the temperatures (min and max).

# %%
plt.figure(figsize=(20, 5))
plt.subplots_adjust(hspace=.5)

# data to plot
n_groups = 3  #3 years


# create plots

plt.subplot(1,4,1) 
plt.plot(_5k_trend_male, color='orange', label = 'Male')
plt.plot(_5k_trend_fem, color='green', label = 'Female')
plt.ylim([20, 30])
plt.xlabel('Year')
plt.ylabel('Minutes')
plt.title('Avg 5K Time by year')
plt.xticks(index , ('2015', '2016', '2017'))
plt.legend()


plt.subplot(1,4,2) 
plt.plot(mintemp, 'b--')
plt.ylim([0, 60])
plt.xlabel('Year')
plt.ylabel('Temp (F)')
plt.title('Min Temp by year')
plt.xticks(index , ('2015', '2016', '2017'))
 


plt.subplot(1,4,3) 
plt.plot(time_trend_male, color='orange', label = 'Male')
plt.plot(time_trend_fem, color='green', label = 'Female')
plt.ylim([200, 280])
plt.xlabel('Year')
plt.ylabel('Minutes')
plt.title('Avg Finish Time by year')
plt.xticks(index, ('2015', '2016', '2017'))
plt.legend()



plt.subplot(1,4,4) 
plt.plot(maxtemp, 'r--')
plt.ylim([30, 80])
plt.xlabel('Year')
plt.ylabel('Temp (F)')
plt.title('Max Temp by year')
plt.xticks(index, ('2015', '2016', '2017'))
 
plt.show()
